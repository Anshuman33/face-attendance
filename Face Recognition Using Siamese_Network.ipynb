# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshuman33/face-attendance/blob/main/Face%20Recognition%20Using%20Siamese_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries

# %%
import os
import numpy as np
import PIL as pil
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D,Flatten,Input,Dense,Lambda,Dropout, MaxPool2D
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras.backend as K

# %% [markdown]
# # Loading the dataset

# %%
DATAPATH = "/content/drive/MyDrive/AI Project/cropped_images"

# %%
# Get the cropped face images dataset
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(DATAPATH,
                                              target_size=(128, 128),
                                              subset="training")
val_generator = train_datagen.flow_from_directory(DATAPATH,
                                              target_size=(128, 128),
                                              subset="validation")
# Out:
# Found 65 images belonging to 5 classes.
# Found 14 images belonging to 5 classes.

# %%
def datagen_to_np_array(generator):
    images, labels = [], []
    generator.reset()
    for i in range(len(generator)):
        batch_X, batch_Y = generator.next()
        images.append(batch_X)
        labels.append(batch_Y)
    images = np.concatenate(images, axis = 0)
    labels = np.concatenate(labels, axis = 0)
    labels = np.argmax(labels, axis = 1)
    return images, labels

def create_pairs_from_dataset(images, labels):
    '''
        Creates similar and dissimilar pairs of images from image and label set.
    '''
    # Find the indices belonging to each class
    label_indices = [np.where(labels == i)[0] for i in range(5)]

    # Get pairs of images and corresponding similarity label
    pairs, y = create_pairs(images, label_indices)
    y = y.astype('float32')
    return pairs, y

def create_pairs(images, label_indices):
    '''Positive and negative pair creation. Alternates between positive and
    negative pairs'''
    pairs = []
    similarity_labels = []
    
    n = min([len(label_index) for label_index in label_indices]) - 1
    
    for class_index in range(5):
        for i in range(n):
            # Gets indices for same class images and add similar pairs to pairs list
            z1, z2 = label_indices[class_index][i], label_indices[class_index][i+1]
            pairs.append([images[z1], images[z2]])

            # Gets indices for different class images and add dissimilar pair to pairs list
            inc = np.random.randint(1, 5)
            diff_class_index = (class_index + inc) % 5
            z1, z2 = label_indices[class_index][i], label_indices[diff_class_index][i]
            pairs.append([images[z1], images[z2]])

            # Adds labels for above two pairs
            similarity_labels += [1, 0]

    return np.array(pairs), np.array(similarity_labels)

# %%
train_images, train_labels = datagen_to_np_array(train_generator)
val_images, val_labels = datagen_to_np_array(val_generator)

# %%
print("Train images array shape: ", train_images.shape)
print("Val images array shape: ", val_images.shape)
print("Train labels array shape: ", train_labels.shape)
print("Val labels array shape: ", val_labels.shape)
# Out:
# Train images array shape:  (65, 128, 128, 3)
# Val images array shape:  (14, 128, 128, 3)
# Train labels array shape:  (65,)
# Val labels array shape:  (14,)

# %%
train_pairs, train_ys = create_pairs_from_dataset(train_images, train_labels)
val_pairs, val_ys = create_pairs_from_dataset(val_images, val_labels)

# %%
# Visualize pair
def show_image(image):
    plt.figure()
    plt.imshow(image)
    plt.grid(False)
    plt.show()

# %%
train_pairs.shape
# Out:
# (80, 2, 128, 128, 3)

# %%
pair_index = 7
show_image(train_pairs[pair_index][0])
show_image(train_pairs[pair_index][1])

# %% [markdown]
# # Building the Siamese Network

# %%
# Method to create the Base network
def build_base_network():
    input = Input(shape=(128, 128, 3), name="base_input")
    x = Conv2D(32, (3, 3), activation="relu", name="conv1")(input)
    x = MaxPool2D(pool_size=(2,2), name="pool1")(x)
    x = Conv2D(64, (3, 3), activation="relu", name="conv2")(x)
    x = MaxPool2D(pool_size=(2,2), name="pool2")(x)
    x = Flatten(name="flatten_input")(x)
    x = Dense(units=128, activation='relu', name='base_first_dense')(x)
    x = Dropout(0.2, name="first_dropout")(x)
    x = Dense(units=64, activation='relu', name='base_second_dense')(x)
    return Model(inputs=input, outputs=x)

# %%
base_network = build_base_network()
base_network.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_input (InputLayer)     [(None, 128, 128, 3)]     0
#
#  conv1 (Conv2D)              (None, 126, 126, 32)      896
#
#  pool1 (MaxPooling2D)        (None, 63, 63, 32)        0
#
#  conv2 (Conv2D)              (None, 61, 61, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 30, 30, 64)        0
#
#  flatten_input (Flatten)     (None, 57600)             0
#
#  base_first_dense (Dense)    (None, 128)               7372928
#
#  first_dropout (Dropout)     (None, 128)               0
#
#  base_second_dense (Dense)   (None, 64)                8256
#
# =================================================================
# Total params: 7,400,576
# Trainable params: 7,400,576
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(base_network, show_shapes=True)

# %%
# Function computes the euclidean distance between two vectors
def euclidean_distance(vectors):
    vec1, vec2 = vectors
    squared_sum = K.sum(K.square(vec1 - vec2), axis=1, keepdims=True)
    return K.sqrt(K.maximum(squared_sum, K.epsilon()))

def eucl_dist_outshape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
# Creates the entire network
def build_siamese_network():
    input_a = Input(shape=(128, 128, 3), name="input_a")
    output_vector_a = base_network(input_a)

    input_b = Input(shape=(128, 128, 3), name="input_b")
    output_vector_b = base_network(input_b)

    output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_outshape)([output_vector_a, output_vector_b])

    model = Model(inputs=[input_a, input_b], outputs=output)
    return model

# %%
siamese_model = build_siamese_network()
plot_model(siamese_model, show_shapes=True)

# %% [markdown]
# # Creating the loss function

# %%
# Wrapper function to return the contastive loss function with margin
def contrastive_loss_with_margin(margin):
    def contrastive_loss(y_true, y_pred):
        pred_square = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - y_pred, 0))
        return K.mean(y_true * pred_square + (1-y_true)*margin_square)
    return contrastive_loss

# %% [markdown]
# # Training the Network

# %%
opt = tf.keras.optimizers.SGD()
siamese_model.compile(loss=contrastive_loss_with_margin(margin=1.5), optimizer=opt)
history = siamese_model.fit([train_pairs[:, 0], train_pairs[:,1]], train_ys,
                    epochs=100, batch_size=8,
                    validation_data=([val_pairs[:,0], val_pairs[:,1]], val_ys))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 4s 378ms/step - loss: 0.7916 - val_loss: 0.8156
# Epoch 2/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.6346 - val_loss: 0.8319
# Epoch 3/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.6339 - val_loss: 0.6538
# Epoch 4/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.6410 - val_loss: 0.9397
# Epoch 5/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.6779 - val_loss: 0.6864
# Epoch 6/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.4991 - val_loss: 0.7802
# Epoch 7/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.5323 - val_loss: 0.7004
# Epoch 8/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.4939 - val_loss: 0.6243
# Epoch 9/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.5265 - val_loss: 0.5346
# Epoch 10/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.5524 - val_loss: 0.6609
# Epoch 11/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4848 - val_loss: 0.6083
# Epoch 12/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.5008 - val_loss: 0.5564
# Epoch 13/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.5262 - val_loss: 0.5048
# Epoch 14/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4459 - val_loss: 0.4328
# Epoch 15/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.4647 - val_loss: 0.6007
# Epoch 16/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4171 - val_loss: 0.5285
# Epoch 17/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4566 - val_loss: 0.5359
# Epoch 18/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4070 - val_loss: 0.4333
# Epoch 19/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.4090 - val_loss: 0.5718
# Epoch 20/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3790 - val_loss: 0.5527
# Epoch 21/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3675 - val_loss: 0.3303
# Epoch 22/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.3565 - val_loss: 0.3571
# Epoch 23/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.3343 - val_loss: 0.3704
# Epoch 24/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3290 - val_loss: 0.3947
# Epoch 25/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.3035 - val_loss: 0.3366
# Epoch 26/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.3474 - val_loss: 0.6578
# Epoch 27/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.3935 - val_loss: 0.3159
# Epoch 28/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2996 - val_loss: 0.3202
# Epoch 29/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.3002 - val_loss: 0.4058
# Epoch 30/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2872 - val_loss: 0.3292
# Epoch 31/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2995 - val_loss: 0.5558
# Epoch 32/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2811 - val_loss: 0.3184
# Epoch 33/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2495 - val_loss: 0.3003
# Epoch 34/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.2686 - val_loss: 0.2993
# Epoch 35/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2860 - val_loss: 0.3091
# Epoch 36/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2526 - val_loss: 0.3778
# Epoch 37/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.2327 - val_loss: 0.3119
# Epoch 38/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.2280 - val_loss: 0.3064
# Epoch 39/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2407 - val_loss: 0.3491
# Epoch 40/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2424 - val_loss: 0.3718
# Epoch 41/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2054 - val_loss: 0.3327
# Epoch 42/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2122 - val_loss: 0.3275
# Epoch 43/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2161 - val_loss: 0.3531
# Epoch 44/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2206 - val_loss: 0.3272
# Epoch 45/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.2126 - val_loss: 0.3973
# Epoch 46/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.2309 - val_loss: 0.3587
# Epoch 47/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1799 - val_loss: 0.3636
# Epoch 48/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.2185 - val_loss: 0.3297
# Epoch 49/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1875 - val_loss: 0.3503
# Epoch 50/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1867 - val_loss: 0.3356
# Epoch 51/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1719 - val_loss: 0.3829
# Epoch 52/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2032 - val_loss: 0.3381
# Epoch 53/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2178 - val_loss: 0.4237
# Epoch 54/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1706 - val_loss: 0.3747
# Epoch 55/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1671 - val_loss: 0.3468
# Epoch 56/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1715 - val_loss: 0.3599
# Epoch 57/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1668 - val_loss: 0.3399
# Epoch 58/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1654 - val_loss: 0.3495
# Epoch 59/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1850 - val_loss: 0.3948
# Epoch 60/100
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1632 - val_loss: 0.4251
# Epoch 61/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1651 - val_loss: 0.3447
# Epoch 62/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1683 - val_loss: 0.4265
# Epoch 63/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.1438 - val_loss: 0.3630
# Epoch 64/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1405 - val_loss: 0.3709
# Epoch 65/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1635 - val_loss: 0.3580
# Epoch 66/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1384 - val_loss: 0.4035
# Epoch 67/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1409 - val_loss: 0.4034
# Epoch 68/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1442 - val_loss: 0.3944
# Epoch 69/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1538 - val_loss: 0.4254
# Epoch 70/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1422 - val_loss: 0.3778
# Epoch 71/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1350 - val_loss: 0.3971
# Epoch 72/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1550 - val_loss: 0.4056
# Epoch 73/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1545 - val_loss: 0.3826
# Epoch 74/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1472 - val_loss: 0.4595
# Epoch 75/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1480 - val_loss: 0.3425
# Epoch 76/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1271 - val_loss: 0.3844
# Epoch 77/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1873 - val_loss: 0.3698
# Epoch 78/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1457 - val_loss: 0.3580
# Epoch 79/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1386 - val_loss: 0.4775
# Epoch 80/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1284 - val_loss: 0.4292
# Epoch 81/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1291 - val_loss: 0.4037
# Epoch 82/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1211 - val_loss: 0.4076
# Epoch 83/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1448 - val_loss: 0.4120
# Epoch 84/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1199 - val_loss: 0.4227
# Epoch 85/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1017 - val_loss: 0.4160
# Epoch 86/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1063 - val_loss: 0.4342
# Epoch 87/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1267 - val_loss: 0.3939
# Epoch 88/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1221 - val_loss: 0.4232
# Epoch 89/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1129 - val_loss: 0.4670
# Epoch 90/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1300 - val_loss: 0.4357
# Epoch 91/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1284 - val_loss: 0.3904
# Epoch 92/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1205 - val_loss: 0.4507
# Epoch 93/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1142 - val_loss: 0.4160
# Epoch 94/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1054 - val_loss: 0.4001
# Epoch 95/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1108 - val_loss: 0.4134
# Epoch 96/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0857 - val_loss: 0.4526
# Epoch 97/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1121 - val_loss: 0.3950
# Epoch 98/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0961 - val_loss: 0.4234
# Epoch 99/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1208 - val_loss: 0.4624
# Epoch 100/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0881 - val_loss: 0.4038

# %% [markdown]
# # Evaluating the model

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distance'''
    pred = y_pred.ravel() < 
    return np.mean(pred == y_true)

# %%
loss = siamese_model.evaluate(x=[val_pairs[:,0], val_pairs[:,1]], y = val_ys)
y_pred_train = siamese_model.predict([train_pairs[:, 0], train_pairs[:,1]])
train_accuracy = compute_accuracy(train_ys, y_pred_train)

y_pred_val = siamese_model.predict([val_pairs[:, 0], val_pairs[:,1]])
val_accuracy = compute_accuracy(val_ys, y_pred_val)

print("Loss = {} Train Accuracy = {} Test accuracy={}".format(loss, train_accuracy, val_accuracy))
# Out:
# 1/1 [==============================] - 0s 114ms/step - loss: 0.4038
# Loss = 0.4037754535675049 Train Accuracy = 0.8875 Test accuracy=0.5

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label=metric_name)

plot_metrics('loss', 'Loss', ylim=3)

# %% [markdown]
# # Visualizing the results

# %%
# Matplotlib config
def visualize_images():
    plt.rc('image', cmap='gray_r')
    plt.rc('grid', linewidth=0)
    plt.rc('xtick', top=False, bottom=False, labelsize='large')
    plt.rc('ytick', left=False, right=False, labelsize='large')
    plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
    plt.rc('text', color='a8151a')
    plt.rc('figure', facecolor='F0F0F0')# Matplotlib fonts

# Utility to display a row of digits with their predictions
def display_images(left, right, predictions, labels, title, n):
    plt.figure(figsize=(17,3))
    plt.title(title)
    plt.yticks([])
    plt.xticks([])
    plt.grid(None)
    left = np.reshape(left, [n, 128, 128, 3])
    left = np.swapaxes(left, 0, 1)
    left = np.reshape(left, [128, 128*n, 3])
    plt.imshow(left)
    plt.figure(figsize=(17,3))
    plt.yticks([])
    plt.xticks([128*x+64 for x in range(n)], predictions)
    for i, t in enumerate(plt.gca().xaxis.get_ticklabels()):
        if predictions[i] > 0.5: t.set_color('red') # far predictions in red
    plt.grid(None)
    right = np.reshape(right, [n, 128, 128,3])
    right = np.swapaxes(right, 0, 1)
    right = np.reshape(right, [128, 128*n, 3])
    plt.imshow(right)

# %%
# Use the plotting utilities
y_pred_train = np.squeeze(y_pred_train)
indexes = np.random.choice(len(y_pred_train), size=10)
display_images(train_pairs[:,0][indexes], train_pairs[:,1][indexes], y_pred_train[indexes], train_ys[indexes], "Face Matching", 10)
